# %%
from newsapi import NewsApiClient

# %%
newsapi = newsapi = NewsApiClient(api_key='f1e5c4af2d8142b0b4ac8822c54777f1')

# %%
articles = newsapi.get_everything(
                                      sources='cnn',
                                      from_param='2021-03-11',
                                      to='2021-03-12',
                                      language='en',
                                      page_size =20)
articles
# Out:
# {'status': 'ok',
#  'totalResults': 339,
#  'articles': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Manu Raju and Alex Rogers, CNN',
#    'title': "McConnell quietly courts Senate primary candidates 'who can win' regardless of Trump ties",
#    'description': 'Senate Minority Leader Mitch McConnell is quietly maneuvering to field a slate of GOP Senate candidates in critical battleground states, attempting to avoid a repeat of election cycles a decade ago when candidates emerged from primaries only to implode and de…',
#    'url': 'https://www.cnn.com/2021/03/12/politics/mitch-mcconnell-donald-trump-2022-senate-races/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210213165012-mitch-mcconnell-february-13-2021-02-super-tease.jpg',
#    'publishedAt': '2021-03-12T23:46:41Z',
# ...
